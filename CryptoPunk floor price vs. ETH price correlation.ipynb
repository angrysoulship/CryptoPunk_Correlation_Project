# %%
# Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 8) # Adjust the configuration of the plots 

# Read in the data

df = pd.read_csv('/Users/angrysoulsheep/Desktop/CryptoPunk_and_ETH.csv')

# %%
df.head()
# Out:
#          Date  Floor_Price_In_ETH  Avg_Price_In_ETH  CP_Avg_Price_In_ETH  \
# 0  2022-01-18               66.00             66.00            211494.68
# 1  2022-01-17               60.00             68.30            222660.05
# 2  2022-01-16               63.99             67.39            224755.39
# 3  2022-01-15               59.95             66.56            221567.05
# 4  2022-01-14               59.90             64.35            210804.52
#
#    ETH_Avg  Pct_change_eth
# 0  3204.46           -1.70
# 1  3260.03           -2.25
# 2  3334.98            0.18
# 3  3329.05            1.62
# 4  3276.01           -1.56

# %%
# Check on missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# Date - 0.0%
# Floor_Price_In_ETH - 0.0%
# Avg_Price_In_ETH - 0.0%
# CP_Avg_Price_In_ETH - 0.0%
# ETH_Avg - 0.0%
# Pct_change_eth - 0.0%

# %%
# Check on data type for columns

df.dtypes
# Out:
# Date                    object
# Floor_Price_In_ETH     float64
# Avg_Price_In_ETH       float64
# CP_Avg_Price_In_ETH    float64
# ETH_Avg                float64
# Pct_change_eth         float64
# dtype: object

# %%
# change display to all data

pd.set_option('display.max_rows', None)

# %%
df
# Out:
#            Date  Floor_Price_In_ETH  Avg_Price_In_ETH  CP_Avg_Price_In_ETH  \
# 0    2022-01-18               66.00             66.00            211494.68
# 1    2022-01-17               60.00             68.30            222660.05
# 2    2022-01-16               63.99             67.39            224755.39
# 3    2022-01-15               59.95             66.56            221567.05
# 4    2022-01-14               59.90             64.35            210804.52
# 5    2022-01-13               68.88             68.88            229234.53
# 6    2022-01-12               59.69             67.59            223233.80
# 7    2022-01-11               63.63             72.58            228939.63
# 8    2022-01-10               60.00             73.88            229147.91
# 9    2022-01-09               80.00             80.00            251232.17
# 10   2022-01-08               60.95             64.93            205979.30
# ...

# %%
# See correlation matric

correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matric')

plt.xlabel('data')

plt.ylabel('data')

plt.show()

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['ETH_Avg'], y=df['Floor_Price_In_ETH'])
plt.title('ETH price vs CrptoPunk avg price')

plt.xlabel('ETH price')

plt.ylabel('CrptoPunk floor price')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot budget vs Gross using seaborn

sns.regplot(x='ETH_Avg', y='Floor_Price_In_ETH', data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='ETH_Avg', ylabel='Floor_Price_In_ETH'>

# %%
correlation_mat = df.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# Floor_Price_In_ETH   Floor_Price_In_ETH     1.000000
#                      Avg_Price_In_ETH       0.557232
#                      CP_Avg_Price_In_ETH    0.584023
#                      ETH_Avg                0.377590
#                      Pct_change_eth        -0.015417
# Avg_Price_In_ETH     Floor_Price_In_ETH     0.557232
#                      Avg_Price_In_ETH       1.000000
#                      CP_Avg_Price_In_ETH    0.938631
#                      ETH_Avg                0.237647
#                      Pct_change_eth        -0.107260
# CP_Avg_Price_In_ETH  Floor_Price_In_ETH     0.584023
#                      Avg_Price_In_ETH       0.938631
#                      CP_Avg_Price_In_ETH    1.000000
#                      ETH_Avg                0.532716
#                      Pct_change_eth        -0.088596
# ETH_Avg              Floor_Price_In_ETH     0.377590
#                      Avg_Price_In_ETH       0.237647
#                      CP_Avg_Price_In_ETH    0.532716
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# Pct_change_eth       Avg_Price_In_ETH      -0.107260
# Avg_Price_In_ETH     Pct_change_eth        -0.107260
# Pct_change_eth       CP_Avg_Price_In_ETH   -0.088596
# CP_Avg_Price_In_ETH  Pct_change_eth        -0.088596
# ETH_Avg              Pct_change_eth        -0.044392
# Pct_change_eth       ETH_Avg               -0.044392
#                      Floor_Price_In_ETH    -0.015417
# Floor_Price_In_ETH   Pct_change_eth        -0.015417
# Avg_Price_In_ETH     ETH_Avg                0.237647
# ETH_Avg              Avg_Price_In_ETH       0.237647
# Floor_Price_In_ETH   ETH_Avg                0.377590
# ETH_Avg              Floor_Price_In_ETH     0.377590
#                      CP_Avg_Price_In_ETH    0.532716
# CP_Avg_Price_In_ETH  ETH_Avg                0.532716
# Floor_Price_In_ETH   Avg_Price_In_ETH       0.557232
# Avg_Price_In_ETH     Floor_Price_In_ETH     0.557232
# CP_Avg_Price_In_ETH  Floor_Price_In_ETH     0.584023
# Floor_Price_In_ETH   CP_Avg_Price_In_ETH    0.584023
# ...

# %%
correlation = sorted_pairs[(sorted_pairs) > 0.3]

correlation
# Out:
# Floor_Price_In_ETH   ETH_Avg                0.377590
# ETH_Avg              Floor_Price_In_ETH     0.377590
#                      CP_Avg_Price_In_ETH    0.532716
# CP_Avg_Price_In_ETH  ETH_Avg                0.532716
# Floor_Price_In_ETH   Avg_Price_In_ETH       0.557232
# Avg_Price_In_ETH     Floor_Price_In_ETH     0.557232
# CP_Avg_Price_In_ETH  Floor_Price_In_ETH     0.584023
# Floor_Price_In_ETH   CP_Avg_Price_In_ETH    0.584023
# Avg_Price_In_ETH     CP_Avg_Price_In_ETH    0.938631
# CP_Avg_Price_In_ETH  Avg_Price_In_ETH       0.938631
# Floor_Price_In_ETH   Floor_Price_In_ETH     1.000000
# CP_Avg_Price_In_ETH  CP_Avg_Price_In_ETH    1.000000
# Avg_Price_In_ETH     Avg_Price_In_ETH       1.000000
# ETH_Avg              ETH_Avg                1.000000
# Pct_change_eth       Pct_change_eth         1.000000
# dtype: float64

# %%
# Conclusion:
# Floor Price Of CryptoPunk has correlation with ETH price, but not very high.
